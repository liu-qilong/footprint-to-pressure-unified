# %%
import pandas as pd

logs = pd.read_csv('../../experiment/mlp-0618/logs.csv', index_col=0)
logs
# Out:
#        train_loss  test_loss       MAE       MSE
# epoch
# 0        0.100386   0.079428  0.276604  0.079428
# 1        0.075621   0.059091  0.237055  0.059091
# 2        0.057128   0.044417  0.203587  0.044417
# 3        0.042970   0.033147  0.174144  0.033147
# 4        0.031811   0.025852  0.150902  0.025852
# 5        0.025246   0.019989  0.129829  0.019989
# 6        0.019742   0.015484  0.110933  0.015484
# 7        0.015032   0.011811  0.094439  0.011811
# 8        0.011633   0.009612  0.082006  0.009612
# 9        0.009646   0.007814  0.070775  0.007814
# 10       0.007813   0.006507  0.061223  0.006507
# 11       0.006880   0.005591  0.054757  0.005591
# 12       0.005393   0.004832  0.049615  0.004832
# 13       0.004853   0.004358  0.046568  0.004358
# 14       0.004553   0.004157  0.045291  0.004157
# 15       0.004157   0.003654  0.042655  0.003654
# 16       0.004362   0.003759  0.043885  0.003759
# 17       0.003523   0.003367  0.041965  0.003367
# ...

# %%
from matplotlib import pyplot as plt

plt.plot(logs['train_loss'][:30], label='train loss')
plt.plot(logs['test_loss'][:30], label='test loss')

plt.ylabel('MSE loss')
plt.xlabel('epoch')
plt.legend()
plt.grid(linestyle='--')
plt.savefig('loss.pdf')
plt.show()
